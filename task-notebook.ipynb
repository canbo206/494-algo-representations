# %%
import pandas as pd 

notes_df = pd.read_csv('notes-00000.tsv' , sep='\t')

total = len(notes_df)
print(f"The total # of records is {total}")
# Out:
# /var/folders/06/vqf6dx7s0mdbgx_rpjv0hc5m0000gn/T/ipykernel_23553/809635343.py:3: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   notes_df = pd.read_csv('notes-00000.tsv' , sep='\t')
# The total # of records is 2347611
